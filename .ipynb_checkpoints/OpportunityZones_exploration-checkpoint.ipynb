# %% [markdown]
# Authour: Dana Chermesh, Nov 2018
# # Opportunity Zones
# This Ipython notebook explores the official published data regarding Opportunity Zones accross the country.
#
# ## 0. Imports

# %%
import requests
import pandas as pd
import numpy as np

from __future__ import print_function, division
import matplotlib.pylab as pl
import seaborn as sns
sns.set_style('whitegrid')
# import json

# Spatial
import geopandas as gpd
import fiona
import shapely

import statsmodels.formula.api as smf
import statsmodels.api as sm

# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# ## 1. Data aqcuisition and exploration
# The shapefiles were downloaded from https://www.cdfifund.gov/Pages/Opportunity-Zones.aspx; for Direct download click [here](https://www.cdfifund.gov/Documents/Opportunity%20Zones2.zip)

# %%
# reading in data
oz = gpd.GeoDataFrame.from_file("OZ Tracts/DesignatedOZTracts_6.14.shp")

# oz = CSAs.set_index('GEOID')

print(oz.shape)
print(oz.columns)
print(oz.crs) # .crs is the projection of the geometry, important for joining+plotting different geographies
oz.head(2)
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-32-5667e8858577> in <module>()
#       1 # reading in data
# ----> 2 oz = gpd.GeoDataFrame.from_file("OZ Tracts/DesignatedOZTracts_6.14.shp")
#       3
#       4 # oz = CSAs.set_index('GEOID')
#       5
#
# /anaconda3/lib/python3.5/site-packages/geopandas/geodataframe.py in from_file(cls, filename, **kwargs)
#     178         >>> df = geopandas.GeoDataFrame.from_file('nybb.shp')
#     179         """
# --> 180         return geopandas.io.file.read_file(filename, **kwargs)
#     181
#     182     @classmethod
#
# /anaconda3/lib/python3.5/site-packages/geopandas/io/file.py in read_file(filename, bbox, **kwargs)
#      63         reader = fiona.open
#      64
# ---> 65     with reader(path_or_bytes, **kwargs) as features:
#      66         crs = features.crs
#      67         if bbox is not None:
#
# /anaconda3/lib/python3.5/site-packages/fiona/__init__.py in open(path, mode, driver, schema, crs, encoding, layer, vfs, enabled_drivers, crs_wkt)
#     163                 raise IOError("no such archive file: %r" % archive)
#     164         elif path != '-' and not os.path.exists(path):
# --> 165             raise IOError("no such file or directory: %r" % path)
#     166         c = Collection(path, mode, driver=driver, encoding=encoding,
#     167                        layer=layer, vsi=vsi, archive=archive,
#
# OSError: no such file or directory: 'OZ Tracts/DesignatedOZTracts_6.14.shp'

# %%
oz.ACSDATASOU.value_counts()
# Out:
# 2011-2015    8637
# 2012-2016      49
# Name: ACSDATASOU, dtype: int64

# %%
oz.TRACTTYPE.value_counts()
# Out:
# Low-Income Community    8491
# Non-LIC Contiguous       195
# Name: TRACTTYPE, dtype: int64

# %% [markdown]
# ### There are 8,686 tracts designated as Opportunity Zones; each of them has 58 variables obtained from ACS data, mostly (8,637 tracts) from the 5-years estimates of 2011-2015 and some (49 tracts) from 2012-2016.

# %%
fig = pl.figure(figsize=(20,10))
ax = fig.add_subplot(111)

oz.plot(ax=ax, color='#EDFF78', edgecolor='k',linewidth=1.5);
# Counties.plot(ax=ax, color='#EDFF78', edgecolor='k',linewidth=.2, alpha=0.6);
# Places.plot(ax=ax, color='r', edgecolor='k',linewidth=.8);
ax.set_xlim(-127,-68)
ax.set_ylim(24.5,50)
# ax.axis('off')
# Out:
# (24.5, 50)

# %%
oz.iloc[:1,:].T
# Out:
#                                                             0
# ObjectID                                                    6
# STATE_FIPS                                                 01
# CNTY_FIPS                                                 001
# STCOFIPS                                                01001
# TRACT                                                  020700
# FIPS                                              01001020700
# POP2010                                                  2891
# POP10_SQMI                                              321.9
# POP2012                                                  3026
# POP12_SQMI                                            336.971
# WHITE                                                    2333
# BLACK                                                     435
# AMERI_ES                                                   11
# ASIAN                                                      13
# HAWN_PI                                                     3
# HISPANIC                                                   98
# OTHER                                                      43
# MULT_RACE                                                  53
# MALES                                                    1334
# FEMALES                                                  1557
# AGE_UNDER5                                                192
# AGE_5_9                                                   185
# AGE_10_14                                                 183
# AGE_15_19                                                 219
# AGE_20_24                                                 215
# AGE_25_34                                                 385
# AGE_35_44                                                 402
# AGE_45_54                                                 433
# AGE_55_64                                                 317
# AGE_65_74                                                 212
# AGE_75_84                                                 122
# AGE_85_UP                                                  26
# MED_AGE                                                  36.6
# MED_AGE_M                                                34.9
# MED_AGE_F                                                38.4
# HOUSEHOLDS                                               1188
# AVE_HH_SZ                                                 2.4
# HSEHLD_1_M                                                143
# HSEHLD_1_F                                                210
# MARHH_CHD                                                 214
# MARHH_NO_C                                                264
# MHH_CHILD                                                  31
# FHH_CHILD                                                 137
# FAMILIES                                                  767
# AVE_FAM_SZ                                               2.96
# HSE_UNITS                                                1301
# VACANT                                                    113
# OWNER_OCC                                                 774
# RENTER_OCC                                                414
# SQMI                                                     8.98
# OID_                                                        0
# CLICKARROW                                            Alabama
# COUNTY                                                Autauga
# GEO2010                                           01001020700
# TRACTTYPE                                Low-Income Community
# ACSDATASOU                                          2011-2015
# OZONETRACT                                                  1
# geometry    POLYGON ((-86.45036596454837 32.45936503416291...
